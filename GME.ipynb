# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np

# %%
#load the dataset
#Created date as index
#Parse date as datetime format instead of strings
a = pd.read_csv(r"C:\Users\ashwi\GME.csv",index_col=0,parse_dates=True,encoding="ISO-8859-1")
a
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-05-26    4.340000    4.610000    4.330000    4.420000    4.420000
# 2020-05-27    4.570000    4.710000    4.360000    4.690000    4.690000
# 2020-05-28    4.750000    4.760000    4.300000    4.330000    4.330000
# 2020-05-29    4.330000    4.420000    4.050000    4.060000    4.060000
# 2020-06-01    4.120000    4.360000    4.020000    4.130000    4.130000
# ...                ...         ...         ...         ...         ...
# 2021-05-18  174.539993  189.199997  168.270004  180.669998  180.669998
# 2021-05-19  171.990005  178.979996  164.149994  168.830002  168.830002
# 2021-05-20  170.789993  174.910004  166.899994  170.490005  170.490005
# 2021-05-21  171.000000  179.240005  170.330002  176.789993  176.789993
# 2021-05-24  175.850006  183.220001  173.354599  181.139999  181.139999
#
#              Volume
# Date
# 2020-05-26  3545700
# 2020-05-27  3146600
# 2020-05-28  2183900
# 2020-05-29  3961700
# 2020-06-01  2611600
# ...             ...
# 2021-05-18  7738700
# 2021-05-19  4825900
# 2021-05-20  2478200
# 2021-05-21  3648400
# 2021-05-24  1192526
#
# [252 rows x 6 columns]

# %%
a.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
a.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean    59.383055   65.529683   52.919661   58.265992   58.265992
# std     79.730573   89.318605   68.793946   76.677050   76.677050
# min      3.900000    4.050000    3.770000    3.850000    3.850000
# 25%      4.965000    5.242500    4.780000    5.025000    5.025000
# 50%     13.740000   14.360000   13.155000   13.840000   13.840000
# 75%    122.755001  148.402496  103.799999  120.354997  120.354997
# max    379.709991  483.000000  262.269989  347.510010  347.510010
#
#              Volume
# count  2.520000e+02
# mean   1.715876e+07
# std    2.852078e+07
# min    1.192526e+06
# 25%    3.832300e+06
# 50%    7.420400e+06
# 75%    1.507058e+07
# max    1.971579e+08

# %%
#Data Starting from 4th January 2021
a.loc['2021-01-01':]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04   19.000000   19.100000   17.150000   17.250000   17.250000
# 2021-01-05   17.350000   18.080000   17.230000   17.370001   17.370001
# 2021-01-06   17.340000   18.980000   17.330000   18.360001   18.360001
# 2021-01-07   18.469999   19.450001   18.020000   18.080000   18.080000
# 2021-01-08   18.180000   18.299999   17.080000   17.690001   17.690001
# ...                ...         ...         ...         ...         ...
# 2021-05-18  174.539993  189.199997  168.270004  180.669998  180.669998
# 2021-05-19  171.990005  178.979996  164.149994  168.830002  168.830002
# 2021-05-20  170.789993  174.910004  166.899994  170.490005  170.490005
# 2021-05-21  171.000000  179.240005  170.330002  176.789993  176.789993
# 2021-05-24  175.850006  183.220001  173.354599  181.139999  181.139999
#
#               Volume
# Date
# 2021-01-04  10022500
# 2021-01-05   4961500
# 2021-01-06   6056200
# 2021-01-07   6129300
# 2021-01-08   6482000
# ...              ...
# 2021-05-18   7738700
# 2021-05-19   4825900
# 2021-05-20   2478200
# 2021-05-21   3648400
# 2021-05-24   1192526
#
# [98 rows x 6 columns]

# %%
# Calculating Daily change in price of stock
daily_change = a['Open']-a['Close']
daily_change
# Out:
# Date
# 2020-05-26   -0.080000
# 2020-05-27   -0.120000
# 2020-05-28    0.420000
# 2020-05-29    0.270000
# 2020-06-01   -0.010000
#                 ...
# 2021-05-18   -6.130005
# 2021-05-19    3.160003
# 2021-05-20    0.299988
# 2021-05-21   -5.789993
# 2021-05-24   -5.289993
# Length: 252, dtype: float64

# %%
#Daily Percentage change
daily_percentage_change = (a['Close']-a['Open'])/a['Open']*100
daily_percentage_change
# Out:
# Date
# 2020-05-26    1.843318
# 2020-05-27    2.625821
# 2020-05-28   -8.842105
# 2020-05-29   -6.235566
# 2020-06-01    0.242718
#                 ...
# 2021-05-18    3.512092
# 2021-05-19   -1.837318
# 2021-05-20   -0.175647
# 2021-05-21    3.385961
# 2021-05-24    3.008242
# Length: 252, dtype: float64

# %%
a['Close'].iloc[0]
# Out:
# 4.42

# %%
a['Close'].iloc[-1]
# Out:
# 181.139999

# %%
# Calculating Daily change in price of stock
daily_change = a['Open']-a['Close']
daily_change
# Out:
# Date
# 2020-05-26   -0.080000
# 2020-05-27   -0.120000
# 2020-05-28    0.420000
# 2020-05-29    0.270000
# 2020-06-01   -0.010000
#                 ...
# 2021-05-18   -6.130005
# 2021-05-19    3.160003
# 2021-05-20    0.299988
# 2021-05-21   -5.789993
# 2021-05-24   -5.289993
# Length: 252, dtype: float64

# %%
#Daily Percentage change
daily_percentage_change = (a['Close']-a['Open'])/a['Open']*100
daily_percentage_change
# Out:
# Date
# 2020-05-26    1.843318
# 2020-05-27    2.625821
# 2020-05-28   -8.842105
# 2020-05-29   -6.235566
# 2020-06-01    0.242718
#                 ...
# 2021-05-18    3.512092
# 2021-05-19   -1.837318
# 2021-05-20   -0.175647
# 2021-05-21    3.385961
# 2021-05-24    3.008242
# Length: 252, dtype: float64

# %%
normalised_Amt = a['Close']/a['Close'].iloc[0]
normalised_Amt
# Out:
# Date
# 2020-05-26     1.000000
# 2020-05-27     1.061086
# 2020-05-28     0.979638
# 2020-05-29     0.918552
# 2020-06-01     0.934389
#                 ...
# 2021-05-18    40.875565
# 2021-05-19    38.196833
# 2021-05-20    38.572399
# 2021-05-21    39.997736
# 2021-05-24    40.981900
# Name: Close, Length: 252, dtype: float64

# %%
#Calculating the minimum value for "Close" column in our dataset
a['Close'].min()
# Out:
# 3.85

# %%
#Calculating the minimum value for each column in our dataset
a.min()
# Out:
# Open               3.90
# High               4.05
# Low                3.77
# Close              3.85
# Adj Close          3.85
# Volume       1192526.00
# dtype: float64

# %%
#Our first index has the lowest closing price in the dataset
a['Close'].argmin()
# Out:
# 38

# %%
#Looking at the row with Min closing price in comparision to entries after that day
a.iloc[38:42]
# Out:
#             Open  High   Low  Close  Adj Close   Volume
# Date
# 2020-07-20  3.95  4.06  3.77   3.85       3.85  3401100
# 2020-07-21  3.90  4.09  3.88   4.01       4.01  3337900
# 2020-07-22  4.02  4.12  3.92   4.11       4.11  2523500
# 2020-07-23  4.09  4.31  4.06   4.11       4.11  3237200

# %%
a["Close"].max()
# Out:
# 347.51001

# %%
#argmax gives us the index number for the max value
a["Close"].argmax()
# Out:
# 170

# %%
a["Close"].mean()
# Out:
# 58.2659920436508

# %%
#Line Graph for closing price of TSX from 2020-05-13 - 2021-05-13
fig, ax = plt.subplots()
a['Close'].plot(ax=ax)
ax.set_ylabel("Price")
ax.set_title("GME")
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
# Text(0.5, 1.0, 'GME')

# %%
fig, ax = plt.subplots(2, 2)
a['Open'].plot(ax=ax[0, 0], title="Open")
a['High'].plot(ax=ax[0, 1], title="High")
a['Low'].plot(ax=ax[1, 0], title="Low")
a['Close'].plot(ax=ax[1, 1], title="Close")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
# Calculating the daily percentage change in closing price
a['Percentage_Change'] = (a['Close'].pct_change())

# %%
a
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-05-26    4.340000    4.610000    4.330000    4.420000    4.420000
# 2020-05-27    4.570000    4.710000    4.360000    4.690000    4.690000
# 2020-05-28    4.750000    4.760000    4.300000    4.330000    4.330000
# 2020-05-29    4.330000    4.420000    4.050000    4.060000    4.060000
# 2020-06-01    4.120000    4.360000    4.020000    4.130000    4.130000
# ...                ...         ...         ...         ...         ...
# 2021-05-18  174.539993  189.199997  168.270004  180.669998  180.669998
# 2021-05-19  171.990005  178.979996  164.149994  168.830002  168.830002
# 2021-05-20  170.789993  174.910004  166.899994  170.490005  170.490005
# 2021-05-21  171.000000  179.240005  170.330002  176.789993  176.789993
# 2021-05-24  175.850006  183.220001  173.354599  181.139999  181.139999
#
#              Volume  Percentage_Change
# Date
# 2020-05-26  3545700                NaN
# 2020-05-27  3146600           0.061086
# 2020-05-28  2183900          -0.076759
# 2020-05-29  3961700          -0.062356
# 2020-06-01  2611600           0.017241
# ...             ...                ...
# 2021-05-18  7738700           0.000388
# 2021-05-19  4825900          -0.065534
# 2021-05-20  2478200           0.009832
# 2021-05-21  3648400           0.036952
# 2021-05-24  1192526           0.024605
#
# [252 rows x 7 columns]

# %%
#Verification of  Percentage_Change for 2020-05-14
(4.690000-4.420000)/4.420000
# Out:
# 0.061085972850678835

# %%
a['Log returns'] = np.log(a['Close']/a['Close'].shift())

# %%
#Daily standard deviation
a['Log returns'].std()
# Out:
# 0.15082147493383344

# %%
#lifting to the square root of half and we have 252 working days in the market every year and square root of 0.5
volatility = a['Percentage_Change'].std()*252**.5
volatility
# Out:
# 2.752125672697664

# %%
str_vol = str(round(volatility, 3)*100)
print(str_vol,'%')
# Out:
# 275.2 %

# %%
fig, ax = plt.subplots()
a['Log returns'].hist(ax=ax, bins=50, alpha=0.6, color='b')
ax.set_xlabel("Log return")
ax.set_ylabel("Freq of log return")
ax.set_title("GME volatility: " + str_vol + "%")
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
# Text(0.5, 1.0, 'GME volatility: 275.2%')

# %%
# 5 Day moving average
a['MA10'] = a['Close'].rolling(5).mean()
a
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-05-26    4.340000    4.610000    4.330000    4.420000    4.420000
# 2020-05-27    4.570000    4.710000    4.360000    4.690000    4.690000
# 2020-05-28    4.750000    4.760000    4.300000    4.330000    4.330000
# 2020-05-29    4.330000    4.420000    4.050000    4.060000    4.060000
# 2020-06-01    4.120000    4.360000    4.020000    4.130000    4.130000
# ...                ...         ...         ...         ...         ...
# 2021-05-18  174.539993  189.199997  168.270004  180.669998  180.669998
# 2021-05-19  171.990005  178.979996  164.149994  168.830002  168.830002
# 2021-05-20  170.789993  174.910004  166.899994  170.490005  170.490005
# 2021-05-21  171.000000  179.240005  170.330002  176.789993  176.789993
# 2021-05-24  175.850006  183.220001  173.354599  181.139999  181.139999
#
#              Volume  Percentage_Change  Log returns        MA10
# Date
# 2020-05-26  3545700                NaN          NaN         NaN
# 2020-05-27  3146600           0.061086     0.059293         NaN
# 2020-05-28  2183900          -0.076759    -0.079865         NaN
# 2020-05-29  3961700          -0.062356    -0.064385         NaN
# 2020-06-01  2611600           0.017241     0.017094    4.326000
# ...             ...                ...          ...         ...
# 2021-05-18  7738700           0.000388     0.000387  166.095999
# 2021-05-19  4825900          -0.065534    -0.067780  170.904001
# 2021-05-20  2478200           0.009832     0.009784  172.102002
# 2021-05-21  3648400           0.036952     0.036286  175.476001
# 2021-05-24  1192526           0.024605     0.024308  175.583999
#
# [252 rows x 9 columns]

# %%
#exponetial moving average
a['EMA10'] = a['Close'].ewm(span=10, adjust=False).mean()
a
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-05-26    4.340000    4.610000    4.330000    4.420000    4.420000
# 2020-05-27    4.570000    4.710000    4.360000    4.690000    4.690000
# 2020-05-28    4.750000    4.760000    4.300000    4.330000    4.330000
# 2020-05-29    4.330000    4.420000    4.050000    4.060000    4.060000
# 2020-06-01    4.120000    4.360000    4.020000    4.130000    4.130000
# ...                ...         ...         ...         ...         ...
# 2021-05-18  174.539993  189.199997  168.270004  180.669998  180.669998
# 2021-05-19  171.990005  178.979996  164.149994  168.830002  168.830002
# 2021-05-20  170.789993  174.910004  166.899994  170.490005  170.490005
# 2021-05-21  171.000000  179.240005  170.330002  176.789993  176.789993
# 2021-05-24  175.850006  183.220001  173.354599  181.139999  181.139999
#
#              Volume       EMA10
# Date
# 2020-05-26  3545700    4.420000
# 2020-05-27  3146600    4.469091
# 2020-05-28  2183900    4.443802
# 2020-05-29  3961700    4.374020
# 2020-06-01  2611600    4.329652
# ...             ...         ...
# 2021-05-18  7738700  165.168946
# 2021-05-19  4825900  165.834593
# 2021-05-20  2478200  166.681031
# 2021-05-21  3648400  168.519024
# 2021-05-24  1192526  170.813747
#
# [252 rows x 7 columns]

# %%
#moving average is more reactive the ema
fig, ax = plt.subplots()
a[['MA10', 'EMA10']].loc['2020-12-01':].plot(ax=ax)
a['Close'].loc['2020-12-01':].plot(ax=ax, alpha=0.25)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
#moving average is more reactive the ema
fig, ax = plt.subplots()
a[['MA10', 'EMA10']].plot(ax=ax)
a['Close'].loc['2020-12-01':].plot(ax=ax, alpha=0.25)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
exp1 = a['Close'].ewm(span=12, adjust=False).mean()
exp2 = a['Close'].ewm(span=26, adjust=False).mean()
a['MACD'] = exp1 - exp2
a['Signal line'] = a['MACD'].ewm(span=9, adjust=False).mean()

# %%
fig, ax = plt.subplots()
a[['MACD', 'Signal line']].plot(ax=ax)
a['Close'].plot(ax=ax, alpha=0.25, secondary_y=True)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
high14 = a['High'].rolling(14).max()
low14 = a['Low'].rolling(14).min()
a['%K'] = (a['Close'] - low14)*100/(high14 - low14)
a['%D'] = a['%K'].rolling(3).mean()

# %%
fig, ax = plt.subplots()
a[['%K', '%D']].loc['2020-11-01':].plot(ax=ax)
ax.axhline(80, c='r', alpha=0.3)
ax.axhline(20, c='r', alpha=0.3)
a['Close'].loc['2020-11-01':].plot(ax=ax, alpha=0.3, secondary_y=True)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
