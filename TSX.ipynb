# 2021-05-12    0.070002
# 2021-05-13   -0.129999
# Length: 252, dtype: float64

# %%
#Daily Percentage change
daily_percentage_change = (a['Close']-a['Open'])/a['Open']*100
daily_percentage_change
# Out:
# Date
# 2020-05-13   -2.492357
# 2020-05-14    1.177536
# 2020-05-15    0.671441
# 2020-05-19   -0.697776
# 2020-05-20   -0.304079
#                 ...
# 2021-05-07    0.650466
# 2021-05-10   -0.712828
# 2021-05-11    0.690843
# 2021-05-12   -0.241137
# 2021-05-13    0.449202
# Length: 252, dtype: float64

# %%
a['Close'].iloc[0]
# Out:
# 22.299999

# %%
a['Close'].iloc[-1]
# Out:
# 29.07

# %%
norm = a['Close']/a['Close'].iloc[0]
norm
# Out:
# Date
# 2020-05-13    1.000000
# 2020-05-14    1.001794
# 2020-05-15    1.008520
# 2020-05-19    1.021076
# 2020-05-20    1.029148
#                 ...
# 2021-05-07    1.318386
# 2021-05-10    1.311659
# 2021-05-11    1.307175
# 2021-05-12    1.298655
# 2021-05-13    1.303588
# Name: Close, Length: 252, dtype: float64

# %% [markdown]
# ### divide each closing price with the first closing price to find change in the price of stock used to find the reutrn over time if we invested from day 1 there would have been 30% gain in the year

# %%
#Confirmation of correctness
a['Close'].iloc[0]*normalised_Amt.iloc[-1]
# Out:
# 29.07

# %%
a.tail()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2021-05-07  29.209999  29.450001  29.170000  29.400000  29.400000  3181700
# 2021-05-10  29.459999  29.500000  29.250000  29.250000  29.250000  2699600
# 2021-05-11  28.950001  29.170000  28.879999  29.150000  29.150000  6308900
# 2021-05-12  29.030001  29.139999  28.900000  28.959999  28.959999  5097400
# 2021-05-13  28.940001  29.129999  28.940001  29.070000  29.070000  3158729

# %%
#Calculating the minimum value for "Close" column in our dataset
a['Close'].min()
# Out:
# 22.299999

# %%
#Calculating the minimum value for each column in our dataset
a.min()
# Out:
# Open             22.080000
# High             22.389999
# Low              21.850000
# Close            22.299999
# Adj Close        21.610979
# Volume       553000.000000
# dtype: float64

# %%
#Our first index has the lowest closing price in the dataset
a['Close'].argmin()
# Out:
# 0

# %%
#Looking at the row with Min closing price in comparision to entries after that day
a.iloc[0:5]
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2020-05-13  22.870001  22.900000  22.190001  22.299999  21.610979  7121000
# 2020-05-14  22.080000  22.389999  21.850000  22.340000  21.649742  6072400
# 2020-05-15  22.340000  22.520000  22.219999  22.490000  21.795109  3945700
# 2020-05-19  22.930000  22.940001  22.670000  22.770000  22.066460  3998100
# 2020-05-20  23.020000  23.070000  22.930000  22.950001  22.240900  3135300

# %%
a["Close"].max()
# Out:
# 29.4

# %%
#argmax gives us the index number for the max value
a["Close"].argmax()
# Out:
# 247

# %%
#Closing price is the highest on 2021-05-07
a.iloc[-6:]
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2021-05-06  29.139999  29.180000  28.959999  29.139999  29.139999  2600100
# 2021-05-07  29.209999  29.450001  29.170000  29.400000  29.400000  3181700
# 2021-05-10  29.459999  29.500000  29.250000  29.250000  29.250000  2699600
# 2021-05-11  28.950001  29.170000  28.879999  29.150000  29.150000  6308900
# 2021-05-12  29.030001  29.139999  28.900000  28.959999  28.959999  5097400
# 2021-05-13  28.940001  29.129999  28.940001  29.070000  29.070000  3158729

# %%
a["Close"].mean()
# Out:
# 25.81603175396825

# %%
# #Dropping columns that are not useful to us yet
# a.drop(labels=['High','Low','Adj Close','Volume'],axis=1, inplace =True)

# %%
a.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2020-05-13  22.870001  22.900000  22.190001  22.299999  21.610979  7121000
# 2020-05-14  22.080000  22.389999  21.850000  22.340000  21.649742  6072400
# 2020-05-15  22.340000  22.520000  22.219999  22.490000  21.795109  3945700
# 2020-05-19  22.930000  22.940001  22.670000  22.770000  22.066460  3998100
# 2020-05-20  23.020000  23.070000  22.930000  22.950001  22.240900  3135300

# %%
#Line Graph for closing price of TSX from 2020-05-13 - 2021-05-13
fig, ax = plt.subplots()
a['Close'].plot(ax=ax)
ax.set_ylabel("Price")
ax.set_title("TSX")
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
# Text(0.5, 1.0, 'TSX')

# %%
fig, ax = plt.subplots(2, 2)
a['Open'].plot(ax=ax[0, 0], title="Open")
a['High'].plot(ax=ax[0, 1], title="High")
a['Low'].plot(ax=ax[1, 0], title="Low")
a['Close'].plot(ax=ax[1, 1], title="Close")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
# Calculating the daily percentage change in closing price
a['Percentage_Change'] = a['Close'].pct_change()

# %%
a
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2020-05-13  22.870001  22.900000  22.190001  22.299999  21.610979  7121000
# 2020-05-14  22.080000  22.389999  21.850000  22.340000  21.649742  6072400
# 2020-05-15  22.340000  22.520000  22.219999  22.490000  21.795109  3945700
# 2020-05-19  22.930000  22.940001  22.670000  22.770000  22.066460  3998100
# 2020-05-20  23.020000  23.070000  22.930000  22.950001  22.240900  3135300
# ...               ...        ...        ...        ...        ...      ...
# 2021-05-07  29.209999  29.450001  29.170000  29.400000  29.400000  3181700
# 2021-05-10  29.459999  29.500000  29.250000  29.250000  29.250000  2699600
# 2021-05-11  28.950001  29.170000  28.879999  29.150000  29.150000  6308900
# 2021-05-12  29.030001  29.139999  28.900000  28.959999  28.959999  5097400
# 2021-05-13  28.940001  29.129999  28.940001  29.070000  29.070000  3158729
#
#             Percentage_Change
# Date
# ...

# %%
#Verification of  Percentage_Change for 2020-05-14
(22.340000-22.299999)/22.299999
# Out:
# 0.0017937668965814831

# %%
#to calculate volitality we first need to find log return of percentage change, this log reurns will be used to calculate the standard deviation the formula for standar deviation is:
#the standard deviation is used to find the volitality #volitality is the standard deviation of log returns

# %%
import numpy as np

# %%
#we need log returns as it makes calculations easier later on shift is used log returns are time consistent/ time additive

# %%
a['Log returns'] = np.log(a['Close']/a['Close'].shift())

# %%
#Daily standard deviation
a['Log returns'].std()
# Out:
# 0.008141764375166484

# %%
#log returns are very similar to Percentage_Change

# %%
a
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2020-05-13  22.870001  22.900000  22.190001  22.299999  21.610979  7121000
# 2020-05-14  22.080000  22.389999  21.850000  22.340000  21.649742  6072400
# 2020-05-15  22.340000  22.520000  22.219999  22.490000  21.795109  3945700
# 2020-05-19  22.930000  22.940001  22.670000  22.770000  22.066460  3998100
# 2020-05-20  23.020000  23.070000  22.930000  22.950001  22.240900  3135300
# ...               ...        ...        ...        ...        ...      ...
# 2021-05-07  29.209999  29.450001  29.170000  29.400000  29.400000  3181700
# 2021-05-10  29.459999  29.500000  29.250000  29.250000  29.250000  2699600
# 2021-05-11  28.950001  29.170000  28.879999  29.150000  29.150000  6308900
# 2021-05-12  29.030001  29.139999  28.900000  28.959999  28.959999  5097400
# 2021-05-13  28.940001  29.129999  28.940001  29.070000  29.070000  3158729
#
#             Percentage_Change  Log returns
# Date
# ...

# %% [markdown]
# ### Volatility is a statistical measure of the dispersion of returns for a given security or market index.  In most cases, the higher the volatility, the riskier the security will be. Volatility is often measured as either the standard deviation or variance between returns from that same security or market index. There are other ways to measure volatility, including beta coefficients, option pricing models, and standard deviations of returns.
# ### We have used standard deviation to find volatility

# %%
# a.pct_change().rolling(5).std()*(252**0.5)

# %%
#lifting to the square root of half and we have 252 working days in the market every year and square root of 0.5
volatility = a['Percentage_Change'].std()*252**.5
volatility
# Out:
# 0.129033475127009

# %%
str_vol = str(round(volatility, 3)*100)
print(str_vol,'%')
# Out:
# 12.9 %

# %%
fig, ax = plt.subplots()
a['Log returns'].hist(ax=ax, bins=50, alpha=0.6, color='b')
ax.set_xlabel("Log return")
ax.set_ylabel("Freq of log return")
ax.set_title("TSX volatility: " + str_vol + "%")
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
# Text(0.5, 1.0, 'TSX volatility: 12.9%')

# %% [markdown]
# ### Calculating the 10 day moving average
# #### moving average is a calculation used to analyze data points by creating a series of averages of different subsets of the full data set.
# #### Moving averages are widely used in technical analysis, a branch of investing that seeks to understand and profit from the price movement patterns of securities and indices. moving averages to detect whether a change in momentum is occurring for a security, such as if there is a sudden downward move in a security’s price

# %%
# 5 Day moving average
a['MA10'] = a['Close'].rolling(5).mean()
a
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2020-05-13  22.870001  22.900000  22.190001  22.299999  21.610979  7121000
# 2020-05-14  22.080000  22.389999  21.850000  22.340000  21.649742  6072400
# 2020-05-15  22.340000  22.520000  22.219999  22.490000  21.795109  3945700
# 2020-05-19  22.930000  22.940001  22.670000  22.770000  22.066460  3998100
# 2020-05-20  23.020000  23.070000  22.930000  22.950001  22.240900  3135300
# ...               ...        ...        ...        ...        ...      ...
# 2021-05-07  29.209999  29.450001  29.170000  29.400000  29.400000  3181700
# 2021-05-10  29.459999  29.500000  29.250000  29.250000  29.250000  2699600
# 2021-05-11  28.950001  29.170000  28.879999  29.150000  29.150000  6308900
# 2021-05-12  29.030001  29.139999  28.900000  28.959999  28.959999  5097400
# 2021-05-13  28.940001  29.129999  28.940001  29.070000  29.070000  3158729
#
#             Percentage_Change  Log returns    MA10
# Date
# ...

# %%
#exponetial moving average
a['EMA10'] = a['Close'].ewm(span=10, adjust=False).mean()
a
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2020-05-13  22.870001  22.900000  22.190001  22.299999  21.610979  7121000
# 2020-05-14  22.080000  22.389999  21.850000  22.340000  21.649742  6072400
# 2020-05-15  22.340000  22.520000  22.219999  22.490000  21.795109  3945700
# 2020-05-19  22.930000  22.940001  22.670000  22.770000  22.066460  3998100
# 2020-05-20  23.020000  23.070000  22.930000  22.950001  22.240900  3135300
# ...               ...        ...        ...        ...        ...      ...
# 2021-05-07  29.209999  29.450001  29.170000  29.400000  29.400000  3181700
# 2021-05-10  29.459999  29.500000  29.250000  29.250000  29.250000  2699600
# 2021-05-11  28.950001  29.170000  28.879999  29.150000  29.150000  6308900
# 2021-05-12  29.030001  29.139999  28.900000  28.959999  28.959999  5097400
# 2021-05-13  28.940001  29.129999  28.940001  29.070000  29.070000  3158729
#
#             Percentage_Change  Log returns    MA10      EMA10
# ...

# %%
#moving average is more reactive the ema
fig, ax = plt.subplots()
a[['MA10', 'EMA10']].loc['2020-12-01':].plot(ax=ax)
a['Close'].loc['2020-12-01':].plot(ax=ax, alpha=0.25)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
#moving average is more reactive the ema
fig, ax = plt.subplots()
a[['MA10', 'EMA10']].plot(ax=ax)
a['Close'].loc['2020-12-01':].plot(ax=ax, alpha=0.25)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
exp1 = a['Close'].ewm(span=12, adjust=False).mean()
exp2 = a['Close'].ewm(span=26, adjust=False).mean()
a['MACD'] = exp1 - exp2
a['Signal line'] = a['MACD'].ewm(span=9, adjust=False).mean()

# %%
a
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2020-05-13  22.870001  22.900000  22.190001  22.299999  21.610979  7121000
# 2020-05-14  22.080000  22.389999  21.850000  22.340000  21.649742  6072400
# 2020-05-15  22.340000  22.520000  22.219999  22.490000  21.795109  3945700
# 2020-05-19  22.930000  22.940001  22.670000  22.770000  22.066460  3998100
# 2020-05-20  23.020000  23.070000  22.930000  22.950001  22.240900  3135300
# ...               ...        ...        ...        ...        ...      ...
# 2021-05-07  29.209999  29.450001  29.170000  29.400000  29.400000  3181700
# 2021-05-10  29.459999  29.500000  29.250000  29.250000  29.250000  2699600
# 2021-05-11  28.950001  29.170000  28.879999  29.150000  29.150000  6308900
# 2021-05-12  29.030001  29.139999  28.900000  28.959999  28.959999  5097400
# 2021-05-13  28.940001  29.129999  28.940001  29.070000  29.070000  3158729
#
# ...

# %%
fig, ax = plt.subplots()
a[['MACD', 'Signal line']].plot(ax=ax)
a['Close'].plot(ax=ax, alpha=0.25, secondary_y=True)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
# blue line above orange line= sell

# %%
high14 = a['High'].rolling(14).max()
low14 = a['Low'].rolling(14).min()
a['%K'] = (a['Close'] - low14)*100/(high14 - low14)
a['%D'] = a['%K'].rolling(3).mean()

# %%
fig, ax = plt.subplots()
a[['%K', '%D']].loc['2020-11-01':].plot(ax=ax)
ax.axhline(80, c='r', alpha=0.3)
ax.axhline(20, c='r', alpha=0.3)
a['Close'].loc['2020-11-01':].plot(ax=ax, alpha=0.3, secondary_y=True)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
