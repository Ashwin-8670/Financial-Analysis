# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np

# %%
#load the dataset
#Created date as index
#Parse date as datetime format instead of strings
a = pd.read_csv(r"C:\Users\ashwi\AC.TO.csv",index_col=0,parse_dates=True,encoding="ISO-8859-1")
a
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-05-25  17.000000  17.200001  16.660000  16.760000  16.760000   2423400
# 2020-05-26  17.190001  18.240000  17.160000  17.670000  17.670000   7372000
# 2020-05-27  17.750000  17.780001  15.930000  16.440001  16.440001  17432000
# 2020-05-28  16.700001  16.770000  15.950000  16.000000  16.000000  11509400
# 2020-05-29  15.880000  15.990000  15.540000  15.900000  15.900000   7199400
# ...               ...        ...        ...        ...        ...       ...
# 2021-05-17  25.450001  25.799999  25.120001  25.530001  25.530001   3581800
# 2021-05-18  25.719999  26.309999  25.430000  25.860001  25.860001   3291800
# 2021-05-19  25.500000  26.020000  25.209999  25.950001  25.950001   2789800
# 2021-05-20  26.010000  26.420000  25.660000  25.799999  25.799999   2919200
# 2021-05-21  25.959999  26.100000  25.510000  25.639999  25.639999   2153100
#
# [251 rows x 6 columns]

# %%
a.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
a.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean    20.974661   21.393466   20.486295   20.934701   20.934701
# std      4.272013    4.333514    4.171919    4.266545    4.266545
# min     14.860000   15.000000   14.480000   14.730000   14.730000
# 25%     16.840000   17.095000   16.399999   16.760000   16.760000
# 50%     21.030001   21.389999   20.330000   20.860001   20.860001
# 75%     25.000000   25.380001   24.375000   24.915000   24.915000
# max     30.000000   31.000000   29.700001   29.799999   29.799999
#
#              Volume
# count  2.510000e+02
# mean   5.387101e+06
# std    3.182369e+06
# min    1.139000e+06
# 25%    3.400700e+06
# 50%    4.509900e+06
# 75%    6.289150e+06
# max    2.715840e+07

# %%
#Data Starting from 4th January 2021
a.loc['2021-01-01':]
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2021-01-04  22.950001  23.120001  21.730000  22.110001  22.110001  4241000
# 2021-01-05  21.780001  23.290001  21.750000  23.010000  23.010000  4751900
# 2021-01-06  23.110001  23.469999  22.530001  22.719999  22.719999  4546800
# 2021-01-07  22.950001  23.420000  22.840000  23.200001  23.200001  4570000
# 2021-01-08  23.290001  23.480000  22.670000  22.840000  22.840000  3400600
# ...               ...        ...        ...        ...        ...      ...
# 2021-05-17  25.450001  25.799999  25.120001  25.530001  25.530001  3581800
# 2021-05-18  25.719999  26.309999  25.430000  25.860001  25.860001  3291800
# 2021-05-19  25.500000  26.020000  25.209999  25.950001  25.950001  2789800
# 2021-05-20  26.010000  26.420000  25.660000  25.799999  25.799999  2919200
# 2021-05-21  25.959999  26.100000  25.510000  25.639999  25.639999  2153100
#
# [98 rows x 6 columns]

# %%
# Calculating Daily change in price of stock
daily_change = a['Open']-a['Close']
daily_change
# Out:
# Date
# 2020-05-25    0.240000
# 2020-05-26   -0.479999
# 2020-05-27    1.309999
# 2020-05-28    0.700001
# 2020-05-29   -0.020000
#                 ...
# 2021-05-17   -0.080000
# 2021-05-18   -0.140002
# 2021-05-19   -0.450001
# 2021-05-20    0.210001
# 2021-05-21    0.320000
# Length: 251, dtype: float64

# %%
#Daily Percentage change
daily_percentage_change = (a['Close']-a['Open'])/a['Open']*100
daily_percentage_change
# Out:
# Date
# 2020-05-25   -1.411765
# 2020-05-26    2.792315
# 2020-05-27   -7.380276
# 2020-05-28   -4.191623
# 2020-05-29    0.125945
#                 ...
# 2021-05-17    0.314342
# 2021-05-18    0.544331
# 2021-05-19    1.764710
# 2021-05-20   -0.807386
# 2021-05-21   -1.232666
# Length: 251, dtype: float64

# %%
a['Close'].iloc[0]
# Out:
# 16.76

# %%
a['Close'].iloc[-1]
# Out:
# 25.639999

# %%
normalised_amt = a['Close']/a['Close'].iloc[0]
normalised_amt
# Out:
# Date
# 2020-05-25    1.000000
# 2020-05-26    1.054296
# 2020-05-27    0.980907
# 2020-05-28    0.954654
# 2020-05-29    0.948687
#                 ...
# 2021-05-17    1.523270
# 2021-05-18    1.542959
# 2021-05-19    1.548329
# 2021-05-20    1.539379
# 2021-05-21    1.529833
# Name: Close, Length: 251, dtype: float64

# %%
#Confirmation of correctness
a['Close'].iloc[0]*normalised_amt.iloc[-1]
# Out:
# 25.639999

# %%
#Calculating the minimum value for "Close" column in our dataset
a['Close'].min()
# Out:
# 14.73

# %%
#Calculating the minimum value for each column in our dataset
a.min()
# Out:
# Open              14.86
# High              15.00
# Low               14.48
# Close             14.73
# Adj Close         14.73
# Volume       1139000.00
# dtype: float64

# %%
#Our first index has the lowest closing price in the dataset
a['Close'].argmin()
# Out:
# 110

# %%
#Looking at the row with Min closing price in comparision to entries after that day
a.iloc[110:115]
# Out:
#              Open       High    Low      Close  Adj Close   Volume
# Date
# 2020-10-30  14.99  15.080000  14.50  14.730000  14.730000  4300600
# 2020-11-02  14.86  15.000000  14.48  14.980000  14.980000  3264100
# 2020-11-03  15.25  15.340000  14.89  15.000000  15.000000  2799800
# 2020-11-04  15.02  15.300000  14.66  15.220000  15.220000  2714100
# 2020-11-05  15.31  16.450001  15.30  16.360001  16.360001  5641300

# %%
a["Close"].max()
# Out:
# 29.799999

# %%
#argmax gives us the index number for the max value
a["Close"].argmax()
# Out:
# 202

# %%
a["Close"].mean()
# Out:
# 20.934701262948206

# %%
#Line Graph for closing price of TSX from 2020-05-13 - 2021-05-13
fig, ax = plt.subplots()
a['Close'].plot(ax=ax)
ax.set_ylabel("Price")
ax.set_title("Air Canada")
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
# Text(0.5, 1.0, 'Air Canada')

# %%
fig, ax = plt.subplots(2, 2)
a['Open'].plot(ax=ax[0, 0], title="Open")
a['High'].plot(ax=ax[0, 1], title="High")
a['Low'].plot(ax=ax[1, 0], title="Low")
a['Close'].plot(ax=ax[1, 1], title="Close")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
# Calculating the daily percentage change in closing price
a['Percentage_Change'] = a['Close'].pct_change()
a
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2020-05-25  17.000000  17.200001  16.660000  16.760000  16.760000   2423400
# 2020-05-26  17.190001  18.240000  17.160000  17.670000  17.670000   7372000
# 2020-05-27  17.750000  17.780001  15.930000  16.440001  16.440001  17432000
# 2020-05-28  16.700001  16.770000  15.950000  16.000000  16.000000  11509400
# 2020-05-29  15.880000  15.990000  15.540000  15.900000  15.900000   7199400
# ...               ...        ...        ...        ...        ...       ...
# 2021-05-17  25.450001  25.799999  25.120001  25.530001  25.530001   3581800
# 2021-05-18  25.719999  26.309999  25.430000  25.860001  25.860001   3291800
# 2021-05-19  25.500000  26.020000  25.209999  25.950001  25.950001   2789800
# 2021-05-20  26.010000  26.420000  25.660000  25.799999  25.799999   2919200
# 2021-05-21  25.959999  26.100000  25.510000  25.639999  25.639999   2153100
#
#             Percentage_Change
# Date
# 2020-05-25                NaN
# 2020-05-26           0.054296
# 2020-05-27          -0.069609
# 2020-05-28          -0.026764
# 2020-05-29          -0.006250
# ...                       ...
# 2021-05-17          -0.010465
# 2021-05-18           0.012926
# 2021-05-19           0.003480
# 2021-05-20          -0.005780
# 2021-05-21          -0.006202
#
# [251 rows x 7 columns]

# %%
(17.670000-16.760000)/16.760000
# Out:
# 0.054295942720763726

# %%
a['Log returns'] = np.log(a['Close']/a['Close'].shift())

# %%
np.log(a['Close']/a['Close'].shift())
# Out:
# Date
# 2020-05-25         NaN
# 2020-05-26    0.052873
# 2020-05-27   -0.072151
# 2020-05-28   -0.027129
# 2020-05-29   -0.006270
#                 ...
# 2021-05-17   -0.010520
# 2021-05-18    0.012843
# 2021-05-19    0.003474
# 2021-05-20   -0.005797
# 2021-05-21   -0.006221
# Name: Close, Length: 251, dtype: float64

# %%
#Daily standard deviation
a['Log returns'].std()
# Out:
# 0.03741878569559203

# %%
#lifting to the square root of half and we have 252 working days in the market every year and square root of 0.5
volatility = a['Percentage_Change'].std()*252**.5
volatility
# Out:
# 0.6131297540321957

# %%
str_vol = str(round(volatility, 3)*100)
print(str_vol,'%')
# Out:
# 61.3 %

# %%
fig, ax = plt.subplots()
a['Log returns'].hist(ax=ax, bins=50, alpha=0.6, color='b')
ax.set_xlabel("Log return")
ax.set_ylabel("Freq of log return")
ax.set_title("TSX volatility: " + str_vol + "%")
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
# Text(0.5, 1.0, 'TSX volatility: 61.3%')

# %%
# 5 Day moving average
a['MA10'] = a['Close'].rolling(5).mean()
a
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2020-05-25  17.000000  17.200001  16.660000  16.760000  16.760000   2423400
# 2020-05-26  17.190001  18.240000  17.160000  17.670000  17.670000   7372000
# 2020-05-27  17.750000  17.780001  15.930000  16.440001  16.440001  17432000
# 2020-05-28  16.700001  16.770000  15.950000  16.000000  16.000000  11509400
# 2020-05-29  15.880000  15.990000  15.540000  15.900000  15.900000   7199400
# ...               ...        ...        ...        ...        ...       ...
# 2021-05-17  25.450001  25.799999  25.120001  25.530001  25.530001   3581800
# 2021-05-18  25.719999  26.309999  25.430000  25.860001  25.860001   3291800
# 2021-05-19  25.500000  26.020000  25.209999  25.950001  25.950001   2789800
# 2021-05-20  26.010000  26.420000  25.660000  25.799999  25.799999   2919200
# 2021-05-21  25.959999  26.100000  25.510000  25.639999  25.639999   2153100
#
#             Percentage_Change  Log returns    MA10
# Date
# 2020-05-25                NaN          NaN     NaN
# 2020-05-26           0.054296     0.052873     NaN
# 2020-05-27          -0.069609    -0.072151     NaN
# 2020-05-28          -0.026764    -0.027129     NaN
# 2020-05-29          -0.006250    -0.006270  16.554
# ...                       ...          ...     ...
# 2021-05-17          -0.010465    -0.010520  25.004
# 2021-05-18           0.012926     0.012843  25.194
# 2021-05-19           0.003480     0.003474  25.514
# 2021-05-20          -0.005780    -0.005797  25.788
# 2021-05-21          -0.006202    -0.006221  25.756
#
# [251 rows x 9 columns]

# %%
#exponetial moving average
a['EMA10'] = a['Close'].ewm(span=10, adjust=False).mean()
a
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2020-05-25  17.000000  17.200001  16.660000  16.760000  16.760000   2423400
# 2020-05-26  17.190001  18.240000  17.160000  17.670000  17.670000   7372000
# 2020-05-27  17.750000  17.780001  15.930000  16.440001  16.440001  17432000
# 2020-05-28  16.700001  16.770000  15.950000  16.000000  16.000000  11509400
# 2020-05-29  15.880000  15.990000  15.540000  15.900000  15.900000   7199400
# ...               ...        ...        ...        ...        ...       ...
# 2021-05-17  25.450001  25.799999  25.120001  25.530001  25.530001   3581800
# 2021-05-18  25.719999  26.309999  25.430000  25.860001  25.860001   3291800
# 2021-05-19  25.500000  26.020000  25.209999  25.950001  25.950001   2789800
# 2021-05-20  26.010000  26.420000  25.660000  25.799999  25.799999   2919200
# 2021-05-21  25.959999  26.100000  25.510000  25.639999  25.639999   2153100
#
#             Percentage_Change  Log returns    MA10      EMA10
# Date
# 2020-05-25                NaN          NaN     NaN  16.760000
# 2020-05-26           0.054296     0.052873     NaN  16.925455
# 2020-05-27          -0.069609    -0.072151     NaN  16.837190
# 2020-05-28          -0.026764    -0.027129     NaN  16.684974
# 2020-05-29          -0.006250    -0.006270  16.554  16.542251
# ...                       ...          ...     ...        ...
# 2021-05-17          -0.010465    -0.010520  25.004  25.030597
# 2021-05-18           0.012926     0.012843  25.194  25.181398
# 2021-05-19           0.003480     0.003474  25.514  25.321144
# 2021-05-20          -0.005780    -0.005797  25.788  25.408208
# 2021-05-21          -0.006202    -0.006221  25.756  25.450352
#
# [251 rows x 10 columns]

# %%
#moving average is more reactive the ema
fig, ax = plt.subplots()
a[['MA10', 'EMA10']].plot(ax=ax)
a['Close'].plot(ax=ax, alpha=0.25)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
#moving average is more reactive the ema
fig, ax = plt.subplots()
a[['MA10', 'EMA10']].loc['2020-12-01':].plot(ax=ax)
a['Close'].loc['2020-12-01':].plot(ax=ax, alpha=0.25)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
exp1 = a['Close'].ewm(span=12, adjust=False).mean()
exp2 = a['Close'].ewm(span=26, adjust=False).mean()
a['MACD'] = exp1 - exp2
a['Signal line'] = a['MACD'].ewm(span=9, adjust=False).mean()

# %%
fig, ax = plt.subplots()
a[['MACD', 'Signal line']].plot(ax=ax)
a['Close'].plot(ax=ax, alpha=0.25, secondary_y=True)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
high14 = a['High'].rolling(14).max()
low14 = a['Low'].rolling(14).min()
a['%K'] = (a['Close'] - low14)*100/(high14 - low14)
a['%D'] = a['%K'].rolling(3).mean()

# %%
fig, ax = plt.subplots()
a[['%K', '%D']].loc['2020-11-01':].plot(ax=ax)
ax.axhline(80, c='r', alpha=0.3)
ax.axhline(20, c='r', alpha=0.3)
a['Close'].loc['2020-11-01':].plot(ax=ax, alpha=0.3, secondary_y=True)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
